# %%
var('Z')

n = 11

def more_etas(xi, eta0, n=11):
    eta = [xi, eta0]
    while len(eta) < n:
        m = len(eta)-1
        eta.append(((eta[m-1] - (2*m-1)*eta[m])/Z).simplify_full())
    return eta
        
eta_positive = more_etas(cosh(sqrt(Z)), sinh(sqrt(Z))/sqrt(Z), n=n)
eta_negative = more_etas(cos(sqrt(-Z)), sin(sqrt(-Z))/sqrt(-Z), n=n)
eta_zero = [1]+[0]*(n-1)

def etas(Z, ring=RDF):
    Z = ring(Z)
    return [ring(v.subs(Z=Z)) for v in (eta_positive if Z > 0 else eta_negative if Z < 0 else eta_zero)]

# %%
RF = RealField(1024)

def write_test(Z, spec=''):
    arr = etas(Z, ring=RF)
    bits = {
        '': 64,
        'l': 80,
        'q': 128
    }
    typ = {
        '': 'double',
        'l': 'long double',
        'q': 'float128'
    }
    tol = {
        '': '1e-8',
        'l': '1e-8l',
        'q': '1e-24q'
    }
    
    s = 'testEta<'+typ[spec]+'>(\n'
    s += str(Z.n(bits[spec]))+spec+', '
    s += '{\n'+ ', '.join(str(v.n(bits[spec]))+spec for v in arr) +'\n}, '
    s += tol[spec] + ');'
    return s

# %%
for _Z in [-50, -30, -10, -1, -.2, -.01, .01, .2, 1, 2]:
    print(write_test(_Z, spec='l'))
# Out:
# testEta<long double>(
# -50.000000000000000000000l, {
# 0.70534790630844231151456l, 0.10024812527586706813744l, -0.012101995620651504867543l, -0.0027310822427564316548013l, -0.000031068311862613068129280l, 0.000050272081194362803557927l, 9.6703408522375660030124e-6l, 1.1220333636050084495042e-6l, 9.8321857492550876810843e-8l, 7.0558899756650940531688e-9l, 4.3256544187511444186056e-10l
# }, 1e-8l);
# testEta<long double>(
# -30.000000000000000000000l, {
# 0.69241911159374784000566l, -0.13172645569509122915402l, -0.027471518909627968971990l, 0.0016437299655402440746018l, 0.0011896722912443063115000l, 0.00022279920243899667019660l, 0.000027184017690222124008980l, 2.5408330717815564634062e-6l, 1.9489374143127033384336e-7l, 1.2752434989583284808140e-8l, 7.2992177972151692983385e-10l
# }, 1e-8l);
# testEta<long double>(
# -10.000000000000000000000l, {
# -0.99978607287932590757522l, -0.0065407069689386402127975l, 0.099324536591038726736242l, 0.030451431674205482042152l, 0.0052932621779988683474520l, 0.00066014035717865963900115l, 0.000064800103660906840355835l, 5.2660783091315604913035e-6l, 3.6589143578034460311107e-7l, 2.2229322757360855536252e-8l, 1.2007051094789941005210e-9l
# }, 1e-8l);
# testEta<long double>(
# -1.0000000000000000000000l, {
# 0.54030230586813971740094l, 0.84147098480789650665250l, 0.30116867893975678925157l, 0.062035052011373861102195l, 0.0090065811171125162594084l, 0.0010110158084137527136639l, 0.000092561158611258163566821l, 7.1569363100870855711166e-6l, 4.7901341987394885769542e-7l, 2.8264988022147294314731e-8l, 1.4913765025551456549984e-9l
# }, 1e-8l);
# testEta<long double>(
# -0.20000000000000000000000l, {
# 0.90165559515004528111994l, 0.96699841709957736757398l, 0.32671410974766043227021l, 0.065719560717019646183259l, 0.0094184691871889932304359l, 0.0010486179665165321489603l, 0.000095462557298980551031640l, 7.3508188612695619389223e-6l, 4.9043948761877087175364e-7l, 2.8867265060005686911638e-8l, 1.5200920066290287209913e-9l
# }, 1e-8l);
# testEta<long double>(
# -0.010000000000000000000000l, {
# 0.99500416527802576609556l, 0.99833416646828152306814l, 0.33300011902557569725800l, 0.066619060844556870585691l, 0.0095185197208655670453669l, 0.0010577201502098731877746l, 0.000096163102329164460440516l, 7.3975410935877071087642e-6l, 4.9318874757319734185056e-7l, 2.9012001025301899414453e-8l, 1.5269856934948195148215e-9l
# }, 1e-8l);
# testEta<long double>(
# 0.010000000000000000000000l, {
# 1.0050041680558035989880l, 1.0016675001984402582373l, 0.33366678573633407506846l, 0.066714298943803303191151l, 0.0095291017317559112705559l, 0.0010586821511924297259662l, 0.000096237102404373685980327l, 7.4024744319180182634575e-6l, 4.9347894394485553801122e-7l, 2.9027274518519328915005e-8l, 1.5277130026946456136098e-9l
# }, 1e-8l);
# testEta<long double>(
# 0.20000000000000000000000l, {
# 1.1016778175486346400269l, 1.0336682583854520063587l, 0.34004779581591316834119l, 0.067624354688562506675618l, 0.0096301118655031748154775l, 0.0010678581502014148363764l, 0.000096942568452206440449421l, 7.4494861357199571638747e-6l, 4.9624343923498659524594e-7l, 2.9172735975791175928006e-8l, 1.5346382326830223491700e-9l
# }, 1e-8l);
# testEta<long double>(
# 1.0000000000000000000000l, {
# 1.5430806348152437784779l, 1.1752011936438014568824l, 0.36787944117144232159552l, 0.071562870129474492095811l, 0.010065090524069861116471l, 0.0011072364609854642805131l, 0.000099962375200682591853594l, 7.6503337779557701235217e-6l, 5.0803608725758024781159e-7l, 2.9792469092066406347822e-8l, 1.5641126924513398986164e-9l
# }, 1e-8l);
# testEta<long double>(
# 2.0000000000000000000000l, {
# 2.1781835566085708639892l, 1.3682988720085906790060l, 0.40494234229999009249163l, 0.076735922554310200765535l, 0.010631364764219544331978l, 0.0011581846023866952208447l, 0.00010385167136964367218769l, 7.9081086603074133900515e-6l, 5.2312939282364905851193e-7l, 3.0583883976338756186291e-8l, 1.6016826129451016724897e-9l
# }, 1e-8l);

# %%
print('{'+', '.join([str(v.n(80))+'l' for v in next(zip(*eta_positive[9].taylor(Z, 0, 11).coefficients()))])+'}')
print('{'+', '.join([str(v.n(80))+'l' for v in next(zip(*eta_positive[10].taylor(Z, 0, 11).coefficients()))])+'}')
# Out:
# {2.9019636862774117676078e-8l, 7.6367465428352941252838e-10l, 9.0913649319467787205760e-12l, 6.5879456028599845801275e-14l, 3.2939728014299922900638e-16l, 1.2199899264555527000236e-18l, 3.5057181794699790230564e-21l, 8.0776916577649286245538e-24l, 1.5298658442736607243473e-26l, 2.4283584829740646418211e-29l, 3.2815655175325197862448e-32l, 3.8246684353525871634554e-35l}
# {1.5273493085670588250568e-9l, 3.6365459727787114882304e-11l, 3.9527673617159907480765e-13l, 2.6351782411439938320510e-15l, 1.2199899264555527000236e-17l, 4.2068618153639748276676e-20l, 1.1308768320870900074375e-22l, 2.4477853508378571589557e-25l, 4.3710452693533163552780e-28l, 6.5631310350650395724896e-31l, 8.4142705577756917596020e-34l, 9.3284595984209443011109e-37l}
