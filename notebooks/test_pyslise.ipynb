# %%
import pyslise as ps

# %%
p = ps.Pyslise(lambda x: x*x, 0, 10, 8*1024)

# %%
E = 3
plot(lambda x: p.propagate(E, [0,1], 0, x)[0][0], (0,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
p.propagate(E, [0,1], 0, 3)
# Out:
# (array([ 0.03332699, -0.08887197]), 2.7828219830550056)
