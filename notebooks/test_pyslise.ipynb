# %%
import pyslise as ps
p = ps.Pyslise(lambda x: 25*(x^2+1), -5.5, 5.5, 30)
plot(lambda E: p.calculateError(E, [0,1],[0,1])[2], (30,50))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(lambda E: p.calculateError(E, [0,1], [1,-1])[2], [-50, 100])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
y0 = [0,1]
y1 = [1, -1]
E = 100
(plot(lambda x: p.propagate(E, y0, -5.5, x)[1]/pi, (-5.5, 5.5), color="red")
+plot(lambda x: p.propagate(E, y1, 5.5, x)[1]/pi, (-5.5, 5.5), color="green")).show()
plot(lambda x: p.eigenfunctionCalculator(E, y0, y1)(x)[0], (-pi/2, pi/2)).show()
(plot(lambda E: p.calculateError(E, y0, y1)[0], (-100,10))).show()
# Out:
# Graphics object consisting of 2 graphics primitives
# Graphics object consisting of 1 graphics primitive
# Graphics object consisting of 1 graphics primitive

# %%
plot(lambda E: p.calculateError(E, y0, y1)[2], (-0.7,-0.6))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
y0 = [1,1]
plot(lambda E: (p.propagate(E, y0, -pi/2, .5)[1] - p.propagate(E, y0, pi/2, .5)[1])/pi, (-5,10), color="red")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(lambda E: p.calculateError(E, [0,1], [0,1])[0], (-1,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
M = pi
E = 1
m = .1
s = 0
f = p.propagate(E, [1,-1], s, m)[0][0]/p.propagate(E, [0,1], M, m)[0][0]
plot(lambda x: p.propagate(E, [1,-1], s, x)[0][0], (s,m)) + \
plot(lambda x: f*p.propagate(E, [1,-1], M, x)[0][0], (m,M), color="red")
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
var("x")
a = -13
b = 1
y = function("y")(x)
pretty_print(desolve(diff(y, x) == cos(y)^2 - x*b*sin(y)^2, y, ivar=x, algorithm="fricas"))
# Out:
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# <ipython-input-146-a8faa98b7054> in <module>()
#       3 b = Integer(1)
#       4 y = function("y")(x)
# ----> 5 pretty_print(desolve(diff(y, x) == cos(y)**Integer(2) - x*b*sin(y)**Integer(2), y, ivar=x, algorithm="fricas"))
#
# /home/toon/Documents/sage/local/lib/python2.7/site-packages/sage/calculus/desolvers.pyc in desolve(de, dvar, ics, ivar, show_method, contrib_ode, algorithm)
#     566
#     567     if algorithm == "fricas":
# --> 568         return fricas_desolve(de, dvar, ics, ivar)
#     569     elif algorithm != "maxima":
#     570         raise ValueError("unknown algorithm %s" % algorithm)
#
# /home/toon/Documents/sage/local/lib/python2.7/site-packages/sage/calculus/desolvers.pyc in fricas_desolve(de, dvar, ics, ivar)
#     112     from sage.symbolic.ring import SR
#     113     if ics is None:
# ...

# %%
import numpy as np
var("t, y")
a = 0
b = 1
times = np.array([0, 0.001 .. 1])*4 #/abs(a)
g = Graphics()

for i in [-1 .. 1]:
    break
    h = atan(-1/sqrt(abs(a)))+i*pi
    g += line([(0,h), (times[-1], h)], color="black", thickness=3)
    #h = atan(-1/sqrt(a))+i*pi
    #g += line([(0,h), (times[-1], h)], color="red", thickness=3)
    pass
for initial in [-4,-3.9 .. 4]:
    g += list_plot(zip(times, desolve_odeint(cos(y)^2 + (a+b*t)*sin(y)^2, initial, times, y)[:,0]), plotjoined=True, color=hue(initial/10))
g.show(figsize=[5,10])
# Out:
# Graphics object consisting of 81 graphics primitives

# %%
var("a, x")
solve(cos(x)^2 - a*sin(x)^2 == 0, x)
# Out:
# [sin(x) == -cos(x)/sqrt(a), sin(x) == cos(x)/sqrt(a)]

# %%
y0 =[0,1]
plot(lambda E: (p.propagate(E, y0, 0, pi/2)[1] -  p.propagate(E, y0, pi, pi/2)[1])/pi, (-1.2,10), color="red")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f = p.eigenfunctionCalculator(39, [0,1], [0,1])

# %%
plot(lambda x: f(x)[0], (0,M))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f = function("f")(x)
desolve(diff(f, x, x) == f, f)
# Out:
# _K2*e^(-x) + _K1*e^x

# %%
var("r")
