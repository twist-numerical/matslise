# %%
import pyslise as ps

# %%
mat = ps.Pyslise(lambda x: cos(2*x), 0, pi, 32)

# %%
M = 11
p = ps.Pyslise(lambda x: x*x, 0, M, 32)

# %%
E = 3
m = 9
f = p.propagate(E, [0,1], 0, m)[0][0]/p.propagate(E, [0,1], M, m)[0][0]
plot(lambda x: p.propagate(E, [0,1], 0, x)[0][0], (0,m)) + \
plot(lambda x: f*p.propagate(E, [0,1], M, x)[0][0], (m,M), color="red")
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
p.computeEigenvaluesByIndex(0,10, [0,1],[0,10])
# Out:
# [(0, 3.0000000000002163),
#  (1, 7.000000000160949),
#  (2, 11.000000031470586),
#  (3, 15.000002527390473),
#  (4, 19.000099926078),
#  (5, 23.00211366299702),
#  (6, 27.024593415630527),
#  (7, 31.15909379270804),
#  (8, 35.60842826719577),
#  (9, 40.567154760799895)]

# %%
f = p.eigenfunctionCalculator(3, [0,1], [0,1])

# %%
plot(lambda x: f(x)[0], (0,M))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f = function("f")(x)
desolve(diff(f, x, x) == f, f)
# Out:
# _K2*e^(-x) + _K1*e^x
