# %%
import pyslise as ps

# %%
p = ps.Pyslise(lambda x: 2*5*cos(2*x), -pi/2, pi/2, 32)

# %%
M = 11
p = ps.Pyslise(lambda x: x*x, 0, M, 32)

# %%
M = pi
E = 39
m = 1
f = p.propagate(E, [0,1], 0, m)[0][0]/p.propagate(E, [0,1], M, m)[0][0]
plot(lambda x: p.propagate(E, [0,1], 0, x)[0][0], (0,m)) + \
plot(lambda x: f*p.propagate(E, [0,1], M, x)[0][0], (m,M), color="red")
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(lambda E: p.calculateError(E, [0,1], [0,1])[0], (30,40), color="red")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
p.computeEigenvaluesByIndex(100,120, [0,1],[0,10])
# Out:
# [(100, 10201.001225490283),
#  (101, 10404.00120157655),
#  (102, 10609.001178356035),
#  (103, 10816.001155802198),
#  (104, 11025.001133889762),
#  (105, 11236.001112594633),
#  (106, 11449.00109189384),
#  (107, 11664.001071765466),
#  (108, 11881.001052188603),
#  (109, 12100.001033143284),
#  (110, 12321.001014610434),
#  (111, 12544.000996571836),
#  (112, 12769.000979010065),
#  (113, 12996.000961908463),
#  (114, 13225.000945251093),
#  (115, 13456.0009290227),
#  (116, 13689.00091320868),
#  (117, 13924.000897795044),
#  (118, 14161.000882768387),
#  (119, 14400.000868115865)]

# %%
f = p.eigenfunctionCalculator(39, [0,1], [0,1])

# %%
plot(lambda x: f(x)[0], (0,M))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f = function("f")(x)
desolve(diff(f, x, x) == f, f)
# Out:
# _K2*e^(-x) + _K1*e^x
