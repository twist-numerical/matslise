# %%
from pyslise import PySE2d
var("x, y")
p = PySE2d(fast_callable((1+x^2)*(1+y^2), domain=float, vars=[x, y]), -5.5,5.5, -5.5,5.5, x_count=31, grid_points=3000, N=40)
p

# %%
for M in p.M:
    M = matrix(RDF, M)
    print (M*M.T-M.parent().one()).norm()
# Out:
# 0.9999999999998735
# 0.8793561334797081
# 0.9378648855605458
# 0.9709928271087342
# 0.9273220372810577
# 0.6873907586269374
# 0.3206956214416996
# 0.04072036141357659
# 0.04072036141358948
# 0.32069562144169456
# 0.6873907586269795
# 0.9273220372831931
# 0.9709928271090821
# 0.9378648855605618
# 0.8793561334798256
# 0.9999999999998735

# %%
M = matrix(RDF,p.M[2])
show(M*M.T)
# Out:
# 40 x 40 dense matrix over Real Double Field (use the '.str()' method to see the entries)

# %%
list_plot(M.eigenvalues())
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
for i in range(p.N-3, p.N, 2):
    show(list_plot(zip(p.grid[0], p.sectors[0].eigenfunctions[i])))
# Out:
# Graphics object consisting of 1 graphics primitive
# Graphics object consisting of 1 graphics primitive

# %%
list_plot(zip(p.grid[0], p.sectors[0].eigenfunctions[9] * p.sectors[0].eigenfunctions[9]))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
for i in range(p.N):
    for j in range(p.N):
        print mean(p.sectors[1].eigenfunctions[j] * p.sectors[0].eigenfunctions[i])*11 - p.M[0][j, i]
# Out:
# -0.000111021987799
# 1.65986449e-10
# 5.01954607176e-06
# -1.62406371732e-10
# -2.78077926921e-07
# 1.84558778102e-10
# 1.62790867339e-08
# -1.03750346709e-10
# -9.58783612259e-10
# -6.23339109087e-12
# 9.95890438414e-11
# -2.78650448538e-11
# 1.93809428263e-10
# -0.000110794959009
# -1.0373901594e-10
# 8.67631078909e-06
# 1.31248879306e-10
# -6.20353026676e-07
# -1.40388335982e-11
# 4.29301402622e-08
# -1.39373125403e-10
# -2.77864408736e-09
# -3.20060919273e-11
# 1.39983989602e-10
# -5.01958047514e-06
# -9.53481352988e-11
# -0.000110341294548
# 1.76673056199e-10
# 1.22325392142e-05
# -1.61516374889e-10
# -1.07139935718e-06
# -5.93652203088e-11
# 8.57207354348e-08
# -2.47893541603e-10
# -6.39829285774e-09
# 2.12568236882e-10
# -1.80249985309e-10
# -8.67643347539e-06
# 1.59419118334e-10
# -0.00010966243749
# -2.48998501176e-10
# 1.57274861488e-05
# -2.28056695471e-10
# -1.63071718443e-06
# -1.91797232489e-10
# 1.47801536573e-07
# 8.39346196041e-12
# -1.24959818299e-08
# ...

# %%
# Out:
# -0.31678062867063572
