# %%
from pyslise import PySE2d

def V(x, y):
    return (1 + x**2) * (1 + y**2)

problem = PySE2d(V, -5.5,5.5, -5.5,5.5, tolerance=1e-8)

# %%
problem.findEigenvalues(0,13,60)
# Out:
# [3.195918084268116,
#  5.526743871509819,
#  5.526743876297207,
#  7.557803347944436,
#  8.031272357749542,
#  9.928061052794343,
#  9.928061073208468,
#  11.311817020313505,
#  11.311817051034854,
#  12.103253897904443,
#  12.201178670811952]

# %%
problem.findEigenvalue(8.44)
# Out:
# 8.031272370941092

# %%
problem.__M[5]
# Out:
# array([[ 9.99963942e-01, -4.86872052e-14,  8.49159527e-03,
#          1.50194405e-13,  8.83160960e-05, -1.78457878e-13,
#          9.68209008e-07,  1.62997417e-13,  1.08767706e-08,
#         -1.23422999e-13,  1.23777766e-10,  6.69409938e-14],
#        [ 2.01894041e-14,  9.99891829e-01,  1.64925930e-13,
#          1.47068138e-02, -8.90498613e-14,  1.97466552e-04,
#          2.49145059e-14,  2.56145593e-06,  1.69446625e-14,
#          3.26275541e-08, -6.61283959e-14,  4.10179955e-10],
#        [-8.49159527e-03,  1.54319380e-13,  9.99747612e-01,
#         -1.15141227e-15,  2.07963256e-02,  4.11053055e-14,
#          3.41989215e-04, -6.51084726e-14,  5.12245013e-06,
#         -4.15297177e-15,  7.29494306e-08, -2.39018689e-14],
#        [-1.48759532e-15, -1.47068138e-02, -4.36758531e-14,
#          9.99531307e-01,  1.59684745e-13,  2.68440685e-02,
#         -7.88099621e-14,  5.22334366e-04, -1.24449549e-13,
#          8.87138141e-06,  5.45908840e-15,  1.39695418e-07],
#        [ 8.83160958e-05, -2.11302502e-13, -2.07963256e-02,
#          6.19244795e-14,  9.99242935e-01,  9.07355605e-14,
#          3.28712075e-02, -2.36953450e-13,  7.38585794e-04,
#         -1.69845943e-13,  1.40251482e-05,  1.30201569e-13],
#        [-8.07212345e-14,  1.97466552e-04, -1.37413317e-13,
#         -2.68440685e-02, -2.51914004e-14,  9.98882529e-01,
#         -5.67127464e-14,  3.88853218e-02, -4.31440670e-13,
#          9.90750116e-04, -2.86037235e-14,  2.07993401e-05],
#        [-9.68209211e-07,  3.87298193e-14,  3.41989215e-04,
#         -2.30311587e-13, -3.28712075e-02, -1.64857548e-13,
#          9.98450128e-01, -2.78598802e-13,  4.48895669e-02,
#         -4.02801536e-13,  1.27880651e-03, -1.78912939e-13],
#        [ 6.53074369e-14, -2.56145586e-06, -1.94465019e-15,
#          5.22334366e-04, -3.29479025e-13, -3.88853218e-02,
#         -3.53094692e-13,  9.97945778e-01, -2.57591287e-13,
#          5.08852977e-02, -6.94167552e-13,  1.60272503e-03],
#        [ 1.08766856e-08,  2.12717651e-14, -5.12244986e-06,
#         -1.98044743e-14,  7.38585794e-04, -4.17660650e-13,
#         -4.48895668e-02, -2.29307187e-13,  9.97369533e-01,
#         -5.76231635e-13,  5.68730273e-02, -4.94849288e-13],
#        [-2.41812762e-14,  3.26275302e-08,  1.72149719e-14,
#         -8.87138634e-06,  1.98251943e-15,  9.90750114e-04,
#         -1.46938608e-13, -5.08852985e-02, -4.06302755e-13,
#          9.96721461e-01, -4.03305191e-13,  6.28527933e-02],
#        [-1.23984667e-10, -3.62218320e-14,  7.29494537e-08,
#          5.32446401e-14, -1.40250921e-05,  3.47194422e-13,
#          1.27880652e-03, -1.41390791e-13, -5.68730214e-02,
#         -6.88036664e-14,  9.96001600e-01, -6.13644491e-14],
#        [-1.64727148e-14, -4.11685848e-10, -1.18903943e-14,
#          1.39694008e-07,  3.15313085e-13, -2.07998708e-05,
#          3.97743370e-13,  1.60272493e-03,  3.80809390e-13,
#         -6.28528323e-02,  4.65255527e-13,  9.95210215e-01]])

# %%
from pyslise import PySliseHalf
from math import pi, cos, sin

B = 20
def V(x):
    return -2*B*cos(2*x)+B**2*sin(2*x)**2

problem = PySliseHalf(V, pi/2, tolerance=1e-5)
side = (0, 1)
eigenvalues = problem.computeEigenvaluesByIndex(0, 10, side)

# %%
for i, E in eigenvalues:
    print(f'{i:3} {E:>10.6f}')
# Out:
#   0  -0.000000
#   1  77.916196
#   2 151.462778
#   3 151.463224
#   4 151.463669
#   5 220.154230
#   6 283.094815
#   7 283.250744
#   8 283.408735
#   9 339.370666

# %%
import numpy
import matplotlib.pyplot as plt

xs = numpy.linspace(-pi/2, pi/2, 300)

plt.figure()
plt.title(f'The potential V')
plt.plot(xs, list(map(V, xs)))
plt.legend(['$V(x)$'])
plt.show()
    
for index, E in eigenvalues:
    phi, d_phi = problem.computeEigenfunction(E, side, xs)

    plt.figure()
    plt.title(f'Eigenfunction with E = {E:.5f}')
    plt.plot(xs, phi)
    plt.legend(['$\\varphi(x)$'])
    plt.show()

# %%
from pyslise import PySlise
from math import pi, cos

problem = PySlise(lambda x: 2*cos(2*x),
                  -pi/2, pi/2, tolerance=1e-5)
left = (0, 1)
right = (0, 1)
eigenvalues = problem.computeEigenvaluesByIndex(
    0, 10, left, right)

print('index  eigenvalue     error')
for index, E in eigenvalues:
    error = problem.computeEigenvalueError(E, left, right)
    print(f'{index:>5} {E:>11.5f} {error:>9.1e}')
# Out:
# index  eigenvalue     error
#     0     1.85911   1.9e-08
#     1     3.91702   2.2e-08
#     2     9.07837   2.8e-08
#     3    16.03297   7.5e-08
#     4    25.02085   6.2e-08
#     5    36.01429   3.2e-09
#     6    49.01042   2.7e-08
#     7    64.00794   4.2e-09
#     8    81.00625   2.2e-08
#     9   100.00505   1.7e-08

# %%
import numpy
import matplotlib.pyplot as plt

for index, E in eigenvalues:
    xs = numpy.linspace(-pi/2, pi/2, 300)
    phi, d_phi = problem.computeEigenfunction(E, left, right, xs)

    plt.figure()
    plt.title(f'Eigenfunction with E = {E:.5f}')
    plt.plot(xs, phi, xs, d_phi)
    plt.legend(['$\\varphi(x)$', '$\\frac{d}{dx}\\varphi(x)$'])
    plt.show()

# %%
from pyslise import PySliseHalf
from math import pi, sin, cos
B = 30
problem = PySliseHalf(lambda x: -2*B*cos(2*x)+B**2*sin(2*x)**2,
                    pi/2, tolerance=1e-5)
side = (0, 1)
eigenvalues = problem.computeEigenvaluesByIndex(
  0, 10, left)

# %%
eigenvalues
# Out:
# [(0, -6.4121827813214025e-12),
#  (1, 117.94630766207274),
#  (1, 117.94630766207278),
#  (1, 231.6649293162498),
#  (2, 231.6649292387569),
#  (4, 231.66492939046),
#  (6, 445.2830895802293),
#  (7, 445.2831723022502),
#  (8, 445.28325502912486),
#  (13, 724.2576813500225)]
