# %%
from pyslise import Pyslise
p = Pyslise(lambda x: 2*cos(2*x), 0, pi, tolerance=1e-11)
# p = Pyslise(lambda x: 2*cos(2*x), 0, pi, steps=8)
p

# %%
plot(lambda E: p.propagate(E, [0,1], [0,1], 0, pi)[0][0], (-5, 6))
# Out:
# Graphics object consisting of 1 graphics primitive
